# %% [markdown]
# # Step 10: Model Monitoring (Detecting Data Drift)
#
# ### Objectives:
# - Load the train and production datasets.
# - Use alibi-detect to detect data drift.
# - Print test results in a tabular format.

# %% [markdown]
# ### 1. Install & Import Required Libraries

# %%
# !pip install alibi-detect scikit-learn pandas numpy tabulate
# Out:
# Collecting alibi-detect
#   Downloading alibi_detect-0.12.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: scikit-learn in c:\users\pc\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: pandas in c:\users\pc\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\pc\venv\lib\site-packages (2.1.3)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.0 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (3.10.0)
# Collecting numpy
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting Pillow<11.0.0,>=5.4.1 (from alibi-detect)
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting opencv-python<5.0.0,>=3.2.0 (from alibi-detect)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.3.0 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (1.15.1)
# Collecting scikit-image<0.23,>=0.19 (from alibi-detect)
#   Downloading scikit_image-0.22.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.0.0 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (4.48.0)
# Collecting dill<0.4.0,>=0.3.0 (from alibi-detect)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.28.1 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=1.8.0 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (2.10.5)
# Requirement already satisfied: toml<1.0.0,>=0.10.1 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (0.10.2)
# Collecting catalogue<3.0.0,>=2.0.0 (from alibi-detect)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting numba!=0.54.0,<0.60.0,>=0.50.0 (from alibi-detect)
#   Downloading numba-0.59.1-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pc\venv\lib\site-packages (from alibi-detect) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pc\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pc\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pc\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (3.2.1)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba!=0.54.0,<0.60.0,>=0.50.0->alibi-detect)
#   Downloading llvmlite-0.42.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pc\venv\lib\site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pc\venv\lib\site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\venv\lib\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\venv\lib\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\venv\lib\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\venv\lib\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2024.12.14)
# Requirement already satisfied: networkx>=2.8 in c:\users\pc\venv\lib\site-packages (from scikit-image<0.23,>=0.19->alibi-detect) (3.4.2)
# Collecting imageio>=2.27 (from scikit-image<0.23,>=0.19->alibi-detect)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image<0.23,>=0.19->alibi-detect)
#   Downloading tifffile-2025.3.13-py3-none-any.whl.metadata (32 kB)
# Collecting lazy_loader>=0.3 (from scikit-image<0.23,>=0.19->alibi-detect)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: colorama in c:\users\pc\venv\lib\site-packages (from tqdm<5.0.0,>=4.28.1->alibi-detect) (0.4.6)
# Requirement already satisfied: filelock in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.27.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\pc\venv\lib\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.5.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pc\venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers<5.0.0,>=4.0.0->alibi-detect) (2024.12.0)
# Downloading alibi_detect-0.12.0-py3-none-any.whl (381 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading numba-0.59.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.7 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.2 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.5 MB 5.0 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/39.5 MB 4.4 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/39.5 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.4/39.5 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/39.5 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/39.5 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 6.0/39.5 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 6.8/39.5 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.6/39.5 MB 4.0 MB/s eta 0:00:08
#    -------- ------------------------------- 8.4/39.5 MB 3.9 MB/s eta 0:00:09
#    -------- ------------------------------- 8.7/39.5 MB 3.6 MB/s eta 0:00:09
#    -------- ------------------------------- 8.7/39.5 MB 3.6 MB/s eta 0:00:09
#    --------- ------------------------------ 9.2/39.5 MB 3.3 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/39.5 MB 3.3 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.7/39.5 MB 3.3 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.8/39.5 MB 3.4 MB/s eta 0:00:09
#    ------------ --------------------------- 12.6/39.5 MB 3.4 MB/s eta 0:00:08
#    ------------- -------------------------- 13.4/39.5 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 14.2/39.5 MB 3.5 MB/s eta 0:00:08
#    --------------- ------------------------ 14.9/39.5 MB 3.5 MB/s eta 0:00:08
#    --------------- ------------------------ 15.7/39.5 MB 3.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.8/39.5 MB 3.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.6/39.5 MB 3.5 MB/s eta 0:00:07
#    ------------------ --------------------- 18.4/39.5 MB 3.6 MB/s eta 0:00:06
#    ------------------- -------------------- 19.1/39.5 MB 3.6 MB/s eta 0:00:06
#    -------------------- ------------------- 20.2/39.5 MB 3.6 MB/s eta 0:00:06
#    --------------------- ------------------ 21.0/39.5 MB 3.6 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.8/39.5 MB 3.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.3/39.5 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.5/39.5 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.5/39.5 MB 3.5 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.1/39.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------ --------------- 23.9/39.5 MB 3.3 MB/s eta 0:00:05
#    ------------------------- -------------- 24.9/39.5 MB 3.4 MB/s eta 0:00:05
#    -------------------------- ------------- 26.0/39.5 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/39.5 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 27.5/39.5 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.6/39.5 MB 3.5 MB/s eta 0:00:04
#    ----------------------------- ---------- 29.4/39.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 30.1/39.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/39.5 MB 3.5 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/39.5 MB 3.5 MB/s eta 0:00:03
#    --------------------------------- ------ 32.8/39.5 MB 3.5 MB/s eta 0:00:02
#    --------------------------------- ------ 33.6/39.5 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.3/39.5 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.9/39.5 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------ --- 35.7/39.5 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------ --- 36.2/39.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/39.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/39.5 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 3.4 MB/s eta 0:00:00
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Downloading scikit_image-0.22.0-cp312-cp312-win_amd64.whl (25.0 MB)
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.0 MB 5.6 MB/s eta 0:00:05
#    -- ------------------------------------- 1.8/25.0 MB 5.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.6/25.0 MB 4.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.4/25.0 MB 4.1 MB/s eta 0:00:06
#    ------ --------------------------------- 4.2/25.0 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/25.0 MB 4.0 MB/s eta 0:00:05
#    --------- ------------------------------ 5.8/25.0 MB 4.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.6/25.0 MB 3.9 MB/s eta 0:00:05
#    ------------ --------------------------- 7.6/25.0 MB 3.9 MB/s eta 0:00:05
#    ------------- -------------------------- 8.4/25.0 MB 3.9 MB/s eta 0:00:05
#    -------------- ------------------------- 8.9/25.0 MB 3.8 MB/s eta 0:00:05
#    --------------- ------------------------ 9.4/25.0 MB 3.8 MB/s eta 0:00:05
#    --------------- ------------------------ 10.0/25.0 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.5/25.0 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.0/25.0 MB 3.5 MB/s eta 0:00:05
#    ------------------ --------------------- 11.5/25.0 MB 3.4 MB/s eta 0:00:04
#    ------------------- -------------------- 12.3/25.0 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 13.1/25.0 MB 3.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.9/25.0 MB 3.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.9/25.0 MB 3.5 MB/s eta 0:00:03
#    ------------------------- -------------- 15.7/25.0 MB 3.5 MB/s eta 0:00:03
#    -------------------------- ------------- 16.5/25.0 MB 3.5 MB/s eta 0:00:03
#    --------------------------- ------------ 17.3/25.0 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.8/25.0 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 18.4/25.0 MB 3.4 MB/s eta 0:00:02
#    ------------------------------- -------- 19.7/25.0 MB 3.5 MB/s eta 0:00:02
#    -------------------------------- ------- 20.4/25.0 MB 3.5 MB/s eta 0:00:02
#    --------------------------------- ------ 21.2/25.0 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.0/25.0 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 22.5/25.0 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 23.1/25.0 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 23.6/25.0 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  24.6/25.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.0/25.0 MB 3.4 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading llvmlite-0.42.0-cp312-cp312-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    - -------------------------------------- 0.8/28.1 MB 4.2 MB/s eta 0:00:07
#    -- ------------------------------------- 1.8/28.1 MB 4.8 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/28.1 MB 4.9 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/28.1 MB 4.9 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/28.1 MB 4.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.1/28.1 MB 2.4 MB/s eta 0:00:11
#    ----- ---------------------------------- 3.9/28.1 MB 2.6 MB/s eta 0:00:10
#    ------- -------------------------------- 5.0/28.1 MB 2.8 MB/s eta 0:00:09
#    -------- ------------------------------- 5.8/28.1 MB 2.9 MB/s eta 0:00:08
#    -------- ------------------------------- 6.3/28.1 MB 2.9 MB/s eta 0:00:08
#    --------- ------------------------------ 6.8/28.1 MB 2.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 7.3/28.1 MB 2.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 7.9/28.1 MB 2.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 8.4/28.1 MB 2.7 MB/s eta 0:00:08
#    ------------ --------------------------- 8.7/28.1 MB 2.7 MB/s eta 0:00:08
#    ------------- -------------------------- 9.4/28.1 MB 2.7 MB/s eta 0:00:07
#    -------------- ------------------------- 10.5/28.1 MB 2.8 MB/s eta 0:00:07
#    ---------------- ----------------------- 11.3/28.1 MB 2.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 12.1/28.1 MB 2.9 MB/s eta 0:00:06
#    ------------------ --------------------- 12.8/28.1 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 13.6/28.1 MB 3.0 MB/s eta 0:00:05
#    -------------------- ------------------- 14.4/28.1 MB 3.1 MB/s eta 0:00:05
#    --------------------- ------------------ 15.5/28.1 MB 3.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 16.3/28.1 MB 3.1 MB/s eta 0:00:04
#    ------------------------ --------------- 17.0/28.1 MB 3.2 MB/s eta 0:00:04
#    ------------------------- -------------- 17.8/28.1 MB 3.2 MB/s eta 0:00:04
#    -------------------------- ------------- 18.6/28.1 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 18.9/28.1 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.9/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.4/28.1 MB 3.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 21.0/28.1 MB 3.2 MB/s eta 0:00:03
#    ------------------------------ --------- 21.5/28.1 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 22.0/28.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/28.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 23.6/28.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.4/28.1 MB 3.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 25.2/28.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 26.0/28.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 26.7/28.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 3.2 MB/s eta 0:00:00
# Downloading tifffile-2025.3.13-py3-none-any.whl (226 kB)
# Installing collected packages: tabulate, Pillow, numpy, llvmlite, lazy_loader, dill, catalogue, tifffile, opencv-python, numba, imageio, scikit-image, alibi-detect
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.44.0
#     Uninstalling llvmlite-0.44.0:
#       Successfully uninstalled llvmlite-0.44.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.61.0
#     Uninstalling numba-0.61.0:
#       Successfully uninstalled numba-0.61.0
# Successfully installed Pillow-10.4.0 alibi-detect-0.12.0 catalogue-2.0.10 dill-0.3.9 imageio-2.37.0 lazy_loader-0.4 llvmlite-0.42.0 numba-0.59.1 numpy-1.26.4 opencv-python-4.11.0.86 scikit-image-0.22.0 tabulate-0.9.0 tifffile-2025.3.13
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PC\venv\Lib\site-packages\~=mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PC\venv\Lib\site-packages\~%mpy'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from alibi_detect.cd import KSDrift
from tabulate import tabulate

# %% [markdown]
# ### 2. Load Train & Production Data

# %%
# Load train dataset
train_data_path = "https://raw.githubusercontent.com/riasingh-13/Bank_Marketing_Project/main/datasets/train.parquet"
df_train = pd.read_parquet(train_data_path, engine="pyarrow")

# Load production dataset
prod_data_path = "https://raw.githubusercontent.com/riasingh-13/Bank_Marketing_Project/main/datasets/prod.parquet"
df_prod = pd.read_parquet(prod_data_path, engine="pyarrow")

# Drop target column if present
target_col = "y"
if target_col in df_train.columns:
    df_train = df_train.drop(columns=[target_col])

if target_col in df_prod.columns:
    df_prod = df_prod.drop(columns=[target_col])

# Ensure column names match
df_prod = df_prod[df_train.columns]

# Display dataset sizes
print(f"✅ Train Data Shape: {df_train.shape}")
print(f"✅ Production Data Shape: {df_prod.shape}")
# Out:
# ✅ Train Data Shape: (24712, 20)
# ✅ Production Data Shape: (8238, 20)

# %% [markdown]
# ### 3. Preprocess Data for Drift Detection

# %%
# Convert categorical variables to numeric
df_train_encoded = pd.get_dummies(df_train)
df_prod_encoded = pd.get_dummies(df_prod)

# Ensure both datasets have the same columns
missing_cols = set(df_train_encoded.columns) - set(df_prod_encoded.columns)
for col in missing_cols:
    df_prod_encoded[col] = 0  # Add missing columns with default value

df_prod_encoded = df_prod_encoded[df_train_encoded.columns]  # Reorder columns

# Convert to NumPy arrays for drift detection (WITHOUT preprocess_drift)
X_train = df_train_encoded.values
X_prod = df_prod_encoded.values

print("✅ Data preprocessing completed for drift detection.")
# Out:
# ✅ Data preprocessing completed for drift detection.

# %% [markdown]
# ### 4. Detect Data Drift Using Alibi-Detect

# %%
# Initialize Kolmogorov-Smirnov Drift Detector
cd = KSDrift(X_train, p_val=0.05)

# Run drift test on production data
preds = cd.predict(X_prod)

# Extract results
drift_status = "Drift Detected" if preds["data"]["is_drift"] == 1 else "No Significant Drift"
p_values = preds["data"]["p_val"]
feature_names = df_train_encoded.columns.tolist()

# Prepare table
drift_results = []
for i, feature in enumerate(feature_names):
    drift_results.append([feature, p_values[i], "Drift" if p_values[i] < 0.05 else "No Drift"])

# Display results in tabular format
print("\n📊 **Data Drift Analysis Results:**\n")
print(tabulate(drift_results, headers=["Feature", "p-value", "Drift Status"], tablefmt="grid"))

# Print overall drift status
print(f"\n✅ **Overall Drift Status:** {drift_status}")
# Out:
# 📊 **Data Drift Analysis Results:**
#
# +-------------------------------+-----------+----------------+
# | Feature                       |   p-value | Drift Status   |
# +===============================+===========+================+
# | age                           |  0.166333 | No Drift       |
# +-------------------------------+-----------+----------------+
# | duration                      |  0.498735 | No Drift       |
# +-------------------------------+-----------+----------------+
# | campaign                      |  0.222693 | No Drift       |
# +-------------------------------+-----------+----------------+
# | pdays                         |  0.993563 | No Drift       |
# +-------------------------------+-----------+----------------+
# | previous                      |  0.999986 | No Drift       |
# +-------------------------------+-----------+----------------+
# | emp.var.rate                  |  0.999998 | No Drift       |
# +-------------------------------+-----------+----------------+
# | cons.price.idx                |  0.998293 | No Drift       |
# +-------------------------------+-----------+----------------+
# | cons.conf.idx                 |  0.848049 | No Drift       |
# +-------------------------------+-----------+----------------+
# | euribor3m                     |  0.98424  | No Drift       |
# +-------------------------------+-----------+----------------+
# | nr.employed                   |  0.999998 | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_admin.                    |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_blue-collar               |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_entrepreneur              |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_housemaid                 |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_management                |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_retired                   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_self-employed             |  0.999999 | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_services                  |  0.913182 | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_student                   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_technician                |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_unemployed                |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | job_unknown                   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | marital_divorced              |  0.999728 | No Drift       |
# +-------------------------------+-----------+----------------+
# | marital_married               |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | marital_single                |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | marital_unknown               |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_basic.4y            |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_basic.6y            |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_basic.9y            |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_high.school         |  0.874745 | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_illiterate          |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_professional.course |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_university.degree   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | education_unknown             |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | default_no                    |  0.890694 | No Drift       |
# +-------------------------------+-----------+----------------+
# | default_unknown               |  0.886846 | No Drift       |
# +-------------------------------+-----------+----------------+
# | default_yes                   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | housing_no                    |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | housing_unknown               |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | housing_yes                   |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | loan_no                       |  0.822575 | No Drift       |
# +-------------------------------+-----------+----------------+
# | loan_unknown                  |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | loan_yes                      |  0.996786 | No Drift       |
# +-------------------------------+-----------+----------------+
# | contact_cellular              |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | contact_telephone             |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_apr                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_aug                     |  0.994892 | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_dec                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_jul                     |  0.925738 | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_jun                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_mar                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_may                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_nov                     |  0.998334 | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_oct                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | month_sep                     |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | day_of_week_fri               |  0.968187 | No Drift       |
# +-------------------------------+-----------+----------------+
# | day_of_week_mon               |  0.998415 | No Drift       |
# +-------------------------------+-----------+----------------+
# | day_of_week_thu               |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | day_of_week_tue               |  0.295163 | No Drift       |
# +-------------------------------+-----------+----------------+
# | day_of_week_wed               |  0.999824 | No Drift       |
# +-------------------------------+-----------+----------------+
# | poutcome_failure              |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | poutcome_nonexistent          |  1        | No Drift       |
# +-------------------------------+-----------+----------------+
# | poutcome_success              |  0.999714 | No Drift       |
# +-------------------------------+-----------+----------------+
#
# ✅ **Overall Drift Status:** No Significant Drift
